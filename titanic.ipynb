# %% [markdown]
# <a href="https://colab.research.google.com/github/deboratech/analise_de_dados/blob/main/Lab_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-711ab776-e8df-4af9-a2fc-ca5e72ad31bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-711ab776-e8df-4af9-a2fc-ca5e72ad31bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'titanic (1).csv',
#  'titanic_result.csv',
#  'titanic.csv',
#  'titanic (2).csv',
#  'titanic (3).csv',
#  'sample_data']

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
filter1 = titanic [['Name','Age','Sex','Pclass','Survived']]
filter1
# Out:
#                                                   Name   Age     Sex  Pclass  \
# 0                              Braund, Mr. Owen Harris  22.0    male       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 2                               Heikkinen, Miss. Laina  26.0  female       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 4                             Allen, Mr. William Henry  35.0    male       3
# ..                                                 ...   ...     ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male       2
# 887                       Graham, Miss. Margaret Edith  19.0  female       1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female       3
# 889                              Behr, Mr. Karl Howell  26.0    male       1
# 890                                Dooley, Mr. Patrick  32.0    male       3
#
#      Survived
# 0           0
# ...

# %%
filter1 = filter1.loc[(filter1['Sex'] == 'female') & (filter1['Pclass'] == 1) & (filter1['Survived'] == 1)]
filter1
# Out:
#                                                   Name   Age     Sex  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 11                            Bonnell, Miss. Elizabeth  58.0  female       1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)   NaN  female       1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0  female       1
# ..                                                 ...   ...     ...     ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  45.0  female       1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  48.0  female       1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0  female       1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0  female       1
# 887                       Graham, Miss. Margaret Edith  19.0  female       1
#
#      Survived
# 1           1
# ...

# %%
total_de_mulheres_sobreviventes = filter1['Survived'].sum()
total_de_mulheres_sobreviventes
# Out:
# 91

# %%
filter1.to_csv('titanic_result.csv')

# %%
import pandas as pd
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
filter1 = titanic.sort_values(by='Name')
filter1
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
filter1 = titanic.loc[(titanic['Name'] == 'Abbott, Mr. Rossmore Edward')]
filter1
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 746          747         0       3  Abbott, Mr. Rossmore Edward  male  16.0
#
#      SibSp  Parch     Ticket   Fare Cabin Embarked
# 746      1      1  C.A. 2673  20.25   NaN        S

# %%
filter1 = titanic.loc[(titanic['Name'] == 'van Melkebeke, Mr. Philemon')]
filter1
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex  Age  \
# 868          869         0       3  van Melkebeke, Mr. Philemon  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 868      0      0  345777   9.5   NaN        S

# %%
filter1 = titanic.loc[(titanic['Name'] == 'del Carlo, Mr. Sebastiano')]
filter1
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 361          362         0       2  del Carlo, Mr. Sebastiano  male  29.0
#
#      SibSp  Parch         Ticket     Fare Cabin Embarked
# 361      1      0  SC/PARIS 2167  27.7208   NaN        C
