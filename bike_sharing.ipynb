# %% [markdown]
# <a href="https://colab.research.google.com/github/deboratech/analise_de_dados/blob/main/bike_sharing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Análise de Dados
# ```

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/bike-sharing.csv")

# %%
print(df)
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 0      2011-01-01       1       1     0      1     0           0        6
# 1      2011-01-01       2       1     0      1     1           0        6
# 2      2011-01-01       3       1     0      1     2           0        6
# 3      2011-01-01       4       1     0      1     3           0        6
# 4      2011-01-01       5       1     0      1     4           0        6
# ...           ...     ...     ...   ...    ...   ...         ...      ...
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# ...

# %%
df.head()
# Out:
#      datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 0  2011-01-01       1       1     0      1     0           0        6
# 1  2011-01-01       2       1     0      1     1           0        6
# 2  2011-01-01       3       1     0      1     2           0        6
# 3  2011-01-01       4       1     0      1     3           0        6
# 4  2011-01-01       5       1     0      1     4           0        6
#
#    is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# 0              0                  1  0.24  0.2879      0.81        0.0
# 1              0                  1  0.22  0.2727      0.80        0.0
# 2              0                  1  0.22  0.2727      0.80        0.0
# 3              0                  1  0.24  0.2879      0.75        0.0
# 4              0                  1  0.24  0.2879      0.75        0.0
#
#    casual  registered  total_count
# 0       3          13           16
# 1       8          32           40
# ...

# %%
df.tail()
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# 17374              1                  2  0.26  0.2576      0.60     0.1642
# 17375              1                  2  0.26  0.2576      0.60     0.1642
# 17376              1                  1  0.26  0.2576      0.60     0.1642
# 17377              1                  1  0.26  0.2727      0.56     0.1343
# 17378              1                  1  0.26  0.2727      0.65     0.1343
#
#        casual  registered  total_count
# ...

# %%
df = pd.DataFrame(df)
display(df)
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 0      2011-01-01       1       1     0      1     0           0        6
# 1      2011-01-01       2       1     0      1     1           0        6
# 2      2011-01-01       3       1     0      1     2           0        6
# 3      2011-01-01       4       1     0      1     3           0        6
# 4      2011-01-01       5       1     0      1     4           0        6
# ...           ...     ...     ...   ...    ...   ...         ...      ...
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# ...

# %%
df= df.drop_duplicates()
df= df.dropna()
display(df)
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 0      2011-01-01       1       1     0      1     0           0        6
# 1      2011-01-01       2       1     0      1     1           0        6
# 2      2011-01-01       3       1     0      1     2           0        6
# 3      2011-01-01       4       1     0      1     3           0        6
# 4      2011-01-01       5       1     0      1     4           0        6
# ...           ...     ...     ...   ...    ...   ...         ...      ...
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# ...

# %%
df= df.replace([float('NaN')],'-')

# %% [markdown]
# # a. Qual o tamanho desse dataset?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           17379 non-null  object
#  1   rec_id             17379 non-null  int64
#  2   season             17379 non-null  int64
#  3   year               17379 non-null  int64
#  4   month              17379 non-null  int64
#  5   hour               17379 non-null  int64
#  6   is_holiday         17379 non-null  int64
#  7   weekday            17379 non-null  int64
#  8   is_workingday      17379 non-null  int64
#  9   weather_condition  17379 non-null  int64
#  10  temp               17379 non-null  float64
#  11  atemp              17379 non-null  float64
#  12  humidity           17379 non-null  float64
#  13  windspeed          17379 non-null  float64
#  14  casual             17379 non-null  int64
#  15  registered         17379 non-null  int64
# ...

# %% [markdown]
# # b. Qual a média da coluna windspeed?

# %%
media = df['windspeed'].mean()
print("A média da coluna é:", media)
# Out:
# A média da coluna é: 0.19009760630646177

# %% [markdown]
# # c. Qual a média da coluna temp?

# %%
media = df['temp'].mean()
print("A média da coluna é:", media)
# Out:
# A média da coluna é: 0.4969871684216583

# %% [markdown]
# # d. Quantos registros existem para o ano de 2011?

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['year'] = df['datetime'].dt.year
registros_2011 = len(df[df['year'] == 2011])
print("O número de registros para o ano de 2011 é:", registros_2011)
# Out:
# O número de registros para o ano de 2011 é: 8645

# %% [markdown]
# # e. Quantos registros existem para o ano de 2012?

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['year'] = df['datetime'].dt.year
registros_2011 = len(df[df['year'] == 2012])
print("O número de registros para o ano de 2012 é:", registros_2012)
# Out:
# O número de registros para o ano de 2012 é: 8734

# %% [markdown]
# #f. Quantas locações de bicicletas foram efetuadas em 2011?

# %%
locacoes_2011 = df[df['year'] == 2011]['total_count'].sum()
print("Foram efetuadas", locacoes_2011, "locações de bicicletas em 2011")
# Out:
# Foram efetuadas 1243103 locações de bicicletas em 2011

# %% [markdown]
# # g. Qual estação do ano contém a maior média de locações de bicicletas?

# %%
grupo_por_estacao = df.groupby('season')
media_por_estacao = grupo_por_estacao['total_count'].mean()
estacao_mais_alta = media_por_estacao.idxmax()
print("Estação com a maior média de locações de bicicletas:", estacao_mais_alta)
# Out:
# Estação com a maior média de locações de bicicletas: 3

# %% [markdown]
# # h. Qual estação do ano contém a menor média de locações de bicicletas?

# %%
grupo_por_estacao = df.groupby('season')
media_por_estacao = grupo_por_estacao['total_count'].mean()
estacao_mais_baixa = media_por_estacao.idxmin()
print("Estação com a menor média de locações de bicicletas:", estacao_mais_baixa)
# Out:
# Estação com a menor média de locações de bicicletas: 1

# %% [markdown]
# #i. Qual horário do dia contém a maior média de locações de bicicletas?

# %%
grupo_por_hora = df.groupby('hour')
media_por_hora = grupo_por_hora['total_count'].mean()
horario_mais_alto = media_por_hora.idxmax()
print("O horário que contém a maior média de locações de bicicletas é:", horario_mais_alto,"h")
# Out:
# O horário que contém a maior média de locações de bicicletas é: 17 h

# %% [markdown]
# #j. Qual horário do dia contém a menor média de locações de bicicletas?

# %%
grupo_por_hora = df.groupby('hour')
media_por_hora = grupo_por_hora['total_count'].mean()
horario_mais_baixo = media_por_hora.idxmin()
print("O horário que contém a menor média de locações de bicicletas é:", horario_mais_baixo,"h")
# Out:
# O horário que contém a menor média de locações de bicicletas é: 4 h

# %% [markdown]
# #k. Que dia da semana contém a maior média de locações de bicicletas?

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['dia_semana'] = df['datetime'].dt.day_name()
grupo_por_dia_semana = df.groupby('dia_semana')
media_por_dia_semana = grupo_por_dia_semana['total_count'].mean()
dia_mais_alto = media_por_dia_semana.idxmax()
print("Dia da semana com a maior média de locações de bicicletas é:", dia_mais_alto)
# Out:
# Dia da semana com a maior média de locações de bicicletas é: Thursday

# %% [markdown]
# #l. Que dia da semana contém a menor média de locações de bicicletas?

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['dia_semana'] = df['datetime'].dt.day_name()
grupo_por_dia_semana = df.groupby('dia_semana')
media_por_dia_semana = grupo_por_dia_semana['total_count'].mean()
dia_mais_baixo = media_por_dia_semana.idxmin()
print("Dia da semana com a menor média de locações de bicicletas é:", dia_mais_baixo)
# Out:
# Dia da semana com a menor média de locações de bicicletas é: Sunday

# %% [markdown]
# #m. Às quartas-feiras (weekday = 3), qual o horário do dia que contém a maior média de locações de bicicletas?

# %%
quartas_feiras = df[df['weekday'] == 3]
grupo_por_hora = quartas_feiras.groupby('hour')
media_por_hora = grupo_por_hora['total_count'].mean()
horario_mais_alto = media_por_hora.idxmax()
print("Horário do dia com a maior média de locações de bicicletas às quartas-feiras é:", horario_mais_alto, "h")
# Out:
# Horário do dia com a maior média de locações de bicicletas às quartas-feiras é: 17 h

# %% [markdown]
# #n. Aos sábados (weekday = 6), qual o horário do dia que contém a maior média de locações de bicicletas?

# %%
sabados = df[df['weekday'] == 6]
grupo_por_hora = sabados.groupby('hour')
media_por_hora = grupo_por_hora['total_count'].mean()
horario_mais_alto = media_por_hora.idxmax()
print("Horário do dia com a maior média de locações de bicicletas aos sábados é:", horario_mais_alto, "h")
# Out:
# Horário do dia com a maior média de locações de bicicletas aos sábados é: 13 h
